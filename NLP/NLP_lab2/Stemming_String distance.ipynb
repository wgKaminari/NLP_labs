# %% [markdown]
# # NLP: Lab 2 (Stemming/String distance)

# %% [markdown]
# ## Stemming

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
print(stopwords.words('english'))
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.lancaster import LancasterStemmer
st = LancasterStemmer()
 
# Create Snowball stemmer
snow_stemmer = SnowballStemmer(language='english')

# Create a Porter Stemmer instance
porter_stemmer = PorterStemmer()

# Create a Lancaster Stemmer instance
lancaster_stemmer = LancasterStemmer()

# Example words for stemming
words = ["running", "jumps", "happily", "programming", 'cared','fairly','sportingly']

# Apply stemming to each word
stemmed_words = [porter_stemmer.stem(word) for word in words]
print("===Porter===:")
print("Original words:", words)
print("Stemmed words:", stemmed_words)

print("\n===Snowball===:")
stemmed_words = [snow_stemmer.stem(word) for word in words]
print("Porter:")
print("Original words:", words)
print("Stemmed words:", stemmed_words)

print("\n===Lancaster===:")
stemmed_words = [lancaster_stemmer.stem(word) for word in words]
print("Porter:")
print("Original words:", words)
print("Stemmed words:", stemmed_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]
# ===Porter===:
# Original words: ['running', 'jumps', 'happily', 'programming', 'cared', 'fairly', 'sportingly']
# Stemmed words: ['run', 'jump', 'happili', 'program', 'care', 'fairli', 'sportingli']
#
# ===Snowball===:
# Porter:
# Original words: ['running', 'jumps', 'happily', 'programming', 'cared', 'fairly', 'sportingly']
# Stemmed words: ['run', 'jump', 'happili', 'program', 'care', 'fair', 'sport']
#
# ===Lancaster===:
# Porter:
# Original words: ['running', 'jumps', 'happily', 'programming', 'cared', 'fairly', 'sportingly']
# Stemmed words: ['run', 'jump', 'happy', 'program', 'car', 'fair', 'sport']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Task 0. Compare frequency distributions of stemmed and unstemmed NLTK corpora. Display most commonly used stems from nltk.text corpora on a plot.

# %%
import nltk
from nltk.book import text1  # Moby Dick
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt

# Ensure necessary resources
nltk.download('book')

porter = PorterStemmer()

# Get lowercased words
words = [word.lower() for word in text1 if word.isalpha()]
stemmed_words = [porter.stem(word) for word in words]

# Create frequency distributions
fdist_original = nltk.FreqDist(words)
fdist_stemmed = nltk.FreqDist(stemmed_words)

# Plot top 20 original
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
fdist_original.plot(20, title="Top 20 Original Words")

# Plot top 20 stemmed
plt.subplot(1, 2, 2)
fdist_stemmed.plot(20, title="Top 20 Stemmed Words")

plt.tight_layout()
plt.show()
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\wgkam\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection book

# %% [markdown]
# ## Task 1. Write your own version of stemmer for Ukrainian (or other non-English language) using regular expressions.

# %%
#pip install stanza
import stanza
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting stanza
#   Downloading stanza-1.10.1-py3-none-any.whl.metadata (13 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from stanza) (2.2.3)
# Requirement already satisfied: protobuf>=3.15.0 in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from stanza) (3.19.6)
# Requirement already satisfied: requests in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from stanza) (2.32.3)
# Collecting networkx (from stanza)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting torch>=1.3.0 (from stanza)
#   Downloading torch-2.7.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: tqdm in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from stanza) (4.67.1)
# Collecting filelock (from torch>=1.3.0->stanza)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.3.0->stanza) (4.12.2)
# Collecting sympy>=1.13.3 (from torch>=1.3.0->stanza)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.3.0->stanza) (3.1.5)
# Collecting fsspec (from torch>=1.3.0->stanza)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.3.0->stanza) (75.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from requests->stanza) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from requests->stanza) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from requests->stanza) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from requests->stanza) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from tqdm->stanza) (0.4.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.3.0->stanza)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wgkam\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.3.0->stanza) (3.0.2)
# Downloading stanza-1.10.1-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 9.1 MB/s eta 0:00:00
# Downloading torch-2.7.0-cp313-cp313-win_amd64.whl (212.5 MB)
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    
MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, emoji, torch, stanza
# Successfully installed emoji-2.14.1 filelock-3.18.0 fsspec-2025.3.2 mpmath-1.3.0 networkx-3.4.2 stanza-1.10.1 sympy-1.14.0 torch-2.7.0

# %% [markdown]
# ![Alt text](8583.1569386710.png)

# %%
#stanza.download("uk")
def stemmer_ua(doc):
    for sentence in doc.sentences:
        for word in sentence.words:
            print(f"{word.text} -> {word.lemma}")

words_ua = ['машинами', 'роботою', 'працював', 'вчителем', 'будинок', 'розумний', 'вікна']
nlp = stanza.Pipeline("uk", processors="tokenize,mwt,pos,lemma", tokenize_no_ssplit=True)

#if u want add more words to list
add_to_list = str(input())
words_ua.append(add_to_list)

text = " ".join(words_ua)
doc = nlp(text)

stemmer_ua(doc)
# Out:
# 2025-05-09 17:41:14 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json: 426kB [00:00, 12.2MB/s]
# 2025-05-09 17:41:14 INFO: Downloaded file to C:\Users\wgkam\stanza_resources\resources.json
# 2025-05-09 17:41:15 INFO: Loading these models for language: uk (Ukrainian):
# ===========================
# | Processor | Package     |
# ---------------------------
# | tokenize  | iu          |
# | mwt       | iu          |
# | pos       | iu_charlm   |
# | lemma     | iu_nocharlm |
# ===========================
#
# 2025-05-09 17:41:15 INFO: Using device: cpu
# 2025-05-09 17:41:15 INFO: Loading: tokenize
# 2025-05-09 17:41:15 INFO: Loading: mwt
# 2025-05-09 17:41:15 INFO: Loading: pos
# 2025-05-09 17:41:16 INFO: Loading: lemma
# 2025-05-09 17:41:16 INFO: Done loading processors!
# машинами -> машина
# роботою -> робота
# працював -> працювати
# вчителем -> вчитель
# будинок -> будинок
# розумний -> розумний
# вікна -> вікно

# %% [markdown]
# ## Task 2. Implement Wagner-Fischer (or Vintsyuk) algorithm for string distance. Link.
#
# Modify the algorithm so that substitution operation cost depends on the key proximity on QWERTY keyboard. For inspiration, look at this StackExchange question.
#
# Or consider this table directly:
#
# Implement another modification to the algorithm: include transposition operation, so that you compute a Damerau-Levenshtein distance.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
qwerty = {
    'q': (0, 0), 'w': (0, 1), 'e': (0, 2), 'r': (0, 3), 't': (0, 4), 'y': (0, 5), 'u': (0, 6), 'i': (0, 7), 'o': (0, 8), 'p': (0, 9),
    'a': (1, 0.5), 's': (1, 1.5), 'd': (1, 2.5), 'f': (1, 3.5), 'g': (1, 4.5), 'h': (1, 5.5), 'j': (1, 6.5), 'k': (1, 7.5), 'l': (1, 8.5),
    'z': (2, 1), 'x': (2, 2), 'c': (2, 3), 'v': (2, 4), 'b': (2, 5), 'n': (2, 6), 'm': (2, 7)
}

def qwerty_distance(a, b):
    if a not in qwerty or b not in qwerty:
        return 2
    ax, ay = qwerty[a]
    bx, by = qwerty[b]
    return math.sqrt((ax - bx) ** 2 + (ay - by) ** 2)

def substitution_cost(a, b):
    if a not in qwerty or b not in qwerty:
        return 2.0
    return 0 if a == b else 2.0

def qwerty_cost(a, b):
    return 0 if a == b else qwerty_distance(a, b)

# %% [markdown]
# ### Wagner Fischer

# %%
def wagner_fischer(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = substitution_cost(s1[i-1], s2[j-1])
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
    return dp[m][n]

# %% [markdown]
# ### Wagner Fischer with QWERTY

# %%
def wagner_fischer_qwerty(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0.0] * (n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = qwerty_cost(s1[i-1], s2[j-1])
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
    return dp[m][n]

# %% [markdown]
# ### Demerau Levenshtein

# %%
def damerau_levenshtein(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = substitution_cost(s1[i-1], s2[j-1])
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
            if i > 1 and j > 1 and s1[i-1] == s2[j-2] and s1[i-2] == s2[j-1]:
                dp[i][j] = min(dp[i][j], dp[i-2][j-2] + 1)
    return dp[m][n]

# %% [markdown]
# ### Demerau Levenshtein with QWERTY

# %%
def damerau_levenshtein_qwerty(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0.0] * (n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = qwerty_cost(s1[i-1], s2[j-1])
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
            if i > 1 and j > 1 and s1[i-1] == s2[j-2] and s1[i-2] == s2[j-1]:
                dp[i][j] = min(dp[i][j], dp[i-2][j-2] + 1)
    return dp[m][n]

# %% [markdown]
# ### Vizualization

# %%
test_pairs = [
    ("cat", "cut"), ("cat", "bat"), ("cat", "dog"), ("cat", "qaz"),
    ("cat", "zzz"), ("kitten", "sitting"), ("play", "plaz"),
    ("keyboard", "keyboqrd"), ("example", "exampqe"),
    ("correct", "korrect"), ("hello", "yello"),
    ("function", "punctuon"), ("semantic", "srmzntid"),
    ("alphabet", "qlphqbst"), ("structure", "xzrudtyre")
]

# %%
data = []
for s1, s2 in test_pairs:
    data.append({
        "Word 1": s1,
        "Word 2": s2,
        "Standard WF": wagner_fischer(s1, s2),
        "QWERTY WF": wagner_fischer_qwerty(s1, s2),
        "Standard DL": damerau_levenshtein(s1, s2),
        "QWERTY DL": damerau_levenshtein_qwerty(s1, s2),
    })

df = pd.DataFrame(data)
df_melted = df.melt(id_vars=["Word 1", "Word 2"], var_name="Method", value_name="Distance")
df_melted["Pair"] = df_melted["Word 1"] + " → " + df_melted["Word 2"]

# %%
df.sort_values(by="Standard WF", ascending=False)
# Out:
#        Word 1     Word 2  Standard WF  QWERTY WF  Standard DL  QWERTY DL
# 14  structure  xzrudtyre            8   5.236068            8   5.236068
# 4         cat        zzz            6   5.118034            6   5.118034
# 2         cat        dog            6   4.236068            6   4.236068
# 12   semantic   srmzntid            6   3.236068            6   3.236068
# 13   alphabet   qlphqbst            6   3.354102            6   3.354102
# 5      kitten    sitting            5   5.000000            5   5.000000
# 3         cat        qaz            4   4.000000            4   4.000000
# 11   function   punctuon            4   3.000000            4   3.000000
# 6        play       plaz            2   2.000000            2   2.000000
# 0         cat        cut            2   2.000000            2   2.000000
# 1         cat        bat            2   2.000000            2   2.000000
# 10      hello      yello            2   1.118034            2   1.118034
# 9     correct    korrect            2   2.000000            2   2.000000
# 8     example    exampqe            2   2.000000            2   2.000000
# 7    keyboard   keyboqrd            2   1.118034            2   1.118034

# %%
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

fig, axes = plt.subplots(2, 2, figsize=(18, 10))
fig.suptitle("Edit Distance Variants", fontsize=18)

methods = ["Standard WF", "QWERTY WF", "Standard DL", "QWERTY DL"]
axes = axes.flatten()

for ax, method in zip(axes, methods):
    subset = df_melted[df_melted["Method"] == method]
    sns.barplot(data=subset, x="Pair", y="Distance", palette="coolwarm", ax=ax)

    ax.set_title(method)
    ax.set_ylim(0, 9)
    ax.tick_params(axis='x', rotation=45)
    ax.grid(True, linestyle="-", alpha=0.5)
    ax.set_axisbelow(True)
    ax.set_ylabel("Distance")

fig.tight_layout(rect=[0, 0, 1, 1])  # Щоб не перекривати заголовок
plt.show()
